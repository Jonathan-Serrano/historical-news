# %%
# %pip install bertopic nltk rdflib
# Out:
# Requirement already satisfied: bertopic in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (0.17.0)
# Requirement already satisfied: nltk in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (3.9.1)
# Requirement already satisfied: rdflib in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (7.1.4)
# Requirement already satisfied: hdbscan>=0.8.29 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from bertopic) (0.8.40)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from bertopic) (2.2.4)
# Requirement already satisfied: pandas>=1.1.5 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from bertopic) (2.2.3)
# Requirement already satisfied: plotly>=4.7.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from bertopic) (6.0.1)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from bertopic) (1.6.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from bertopic) (4.1.0)
# Requirement already satisfied: tqdm>=4.41.1 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from bertopic) (4.67.1)
# Requirement already satisfied: umap-learn>=0.5.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from bertopic) (0.5.7)
# Requirement already satisfied: click in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from rdflib) (3.2.3)
# Requirement already satisfied: scipy>=1.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from hdbscan>=0.8.29->bertopic) (1.15.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from pandas>=1.1.5->bertopic) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from plotly>=4.7.0->bertopic) (1.37.1)
# Requirement already satisfied: packaging in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from plotly>=4.7.0->bertopic) (24.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from scikit-learn>=1.0->bertopic) (3.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (4.51.3)
# Requirement already satisfied: torch>=1.11.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (2.7.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (0.30.2)
# Requirement already satisfied: Pillow in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (4.13.1)
# Requirement already satisfied: colorama in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from tqdm>=4.41.1->bertopic) (0.4.6)
# Requirement already satisfied: numba>=0.51.2 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from umap-learn>=0.5.0->bertopic) (0.61.2)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: filelock in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.3.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (6.0.2)
# Requirement already satisfied: requests in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.32.3)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.44.0)
# Requirement already satisfied: six>=1.5 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.14.0)
# Requirement already satisfied: networkx in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (78.1.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.5.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("memento_data/html_results.csv")

# %%
df.head()
# Out:
#                                     source               channel_title  \
# 0  https://machinelearningmastery.com/feed  MachineLearningMastery.com
# 1  https://machinelearningmastery.com/feed  MachineLearningMastery.com
# 2  https://machinelearningmastery.com/feed  MachineLearningMastery.com
# 3  https://machinelearningmastery.com/feed  MachineLearningMastery.com
# 4  https://machinelearningmastery.com/feed  MachineLearningMastery.com
#
#                              channel_description  \
# 0  Making developers awesome at machine learning
# 1  Making developers awesome at machine learning
# 2  Making developers awesome at machine learning
# 3  Making developers awesome at machine learning
# 4  Making developers awesome at machine learning
#
#                                                title  \
# 0  3 Ways Vibe Coding and AI-Assisted Development...
# 1              Advanced Q&A Features with DistilBERT
# 2  A Gentle Introduction to Attention and Transfo...
# 3  Building a Recommender System From Scratch wit...
# 4  The Beginner’s Guide to Machine Learning with ...
#
#                                          description  \
# 0  Vibe coding and AI-assisted development are tw...
# 1  This post is divided into three parts; they ar...
# 2  This post is divided into three parts; they ar...
# 3  In this article, we will build step by step a ...
# 4  Machine learning has become an essential tool ...
#
#                                                 link  \
# 0  https://machinelearningmastery.com/3-ways-vibe...
# 1  https://machinelearningmastery.com/advanced-qa...
# 2  https://machinelearningmastery.com/a-gentle-in...
# 3  https://machinelearningmastery.com/building-a-...
# 4  https://machinelearningmastery.com/the-beginne...
#
#                            pubDate                     author html
# 0  Mon, 31 Mar 2025 11:00:41 +0000  Iván Palomares Carrascosa  NaN
# 1  Sat, 29 Mar 2025 18:33:57 +0000   Muhammad Asad Iqbal Khan  NaN
# 2  Fri, 28 Mar 2025 14:38:37 +0000                 Adrian Tam  NaN
# 3  Fri, 28 Mar 2025 12:00:08 +0000  Iván Palomares Carrascosa  NaN
# 4  Wed, 26 Mar 2025 16:20:41 +0000              Jayita Gulati  NaN

# %%
# Loading premade topic for guided topic modeling
from rdflib import Graph

files = ["CSO.3.4.1.owl", "NLP-Taxonomy.owl"]
g = Graph()
for file in files:
    g.parse(f"topic_data/{file}", format="xml")

topics = []
for s, p, o in g:
    if p.endswith("label"):
        topics.append(str(o))

# %%
docs = (df["title"].fillna("") + " " + df["description"].fillna("") + df["html"].fillna("")).tolist()

# %%
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired

topic_model = BERTopic(
    calculate_probabilities=True,
    verbose=True,
    zeroshot_topic_list=topics,
    min_topic_size=10,
    zeroshot_min_similarity=0.85,
    representation_model=KeyBERTInspired(),
)
topics, probs = topic_model.fit_transform(docs)
# Out:
# 2025-05-02 22:12:57,171 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/812 [00:00<?, ?it/s]
# 2025-05-02 22:21:47,672 - BERTopic - Embedding - Completed ✓
# 2025-05-02 22:21:47,673 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-05-02 22:22:18,769 - BERTopic - Dimensionality - Completed ✓
# 2025-05-02 22:22:18,771 - BERTopic - Zeroshot Step 1 - Finding documents that could be assigned to either one of the zero-shot topics
# 2025-05-02 22:22:30,723 - BERTopic - Zeroshot Step 1 - Completed ✓
# 2025-05-02 22:22:47,347 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-05-02 22:23:54,847 - BERTopic - Cluster - Completed ✓
# 2025-05-02 22:23:54,847 - BERTopic - Zeroshot Step 2 - Combining topics from zero-shot topic modeling with topics from clustering...
# 2025-05-02 22:23:54,891 - BERTopic - Zeroshot Step 2 - Completed ✓
# 2025-05-02 22:23:54,893 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-05-02 22:24:49,315 - BERTopic - Representation - Completed ✓

# %%
# multilabel_topics = []
# for prob_dist in probs:
#     multilabel = [i for i, prob in enumerate(prob_dist) if prob > 0.3]
#     multilabel_topics.append(multilabel)
multilabel_topics_top = [list(np.argsort(prob)[-5:][::-1]) for prob in probs]

# %%
from sklearn.cluster import DBSCAN
import numpy as np
multilabel_topics = []

for prob in probs:
    # Reshape to 2D for clustering
    prob_2d = np.array(prob).reshape(-1, 1)

    # Cluster the probabilities
    clustering = DBSCAN(eps=0.05, min_samples=1).fit(prob_2d)

    # Find the cluster with the highest mean probability
    labels = clustering.labels_
    cluster_means = {label: prob_2d[labels == label].mean() for label in set(labels)}
    top_cluster_label = max(cluster_means, key=cluster_means.get)

    # Get topic indices in that top cluster
    selected_topics = [
        i for i, label in enumerate(labels) if label == top_cluster_label
    ]
    
    # If selected_topics is greater than 5, keep only the top 5
    if len(selected_topics) > 5:
        selected_topics = sorted(selected_topics, key=lambda x, p=prob: p[x], reverse=True)[:3]
    multilabel_topics.append(selected_topics)

# %%
topic_info = topic_model.get_topic_info()
topic_info.to_csv("memento_data/bertopic_topics.csv", index=False)

# %%
topic_model.visualize_topics().show()

# %%
topic_info = topic_model.get_topic_info()
id2label = dict(zip(topic_info.Topic, topic_info.Name))

# %%
topics = [id2label[t] for t in topics]

# %%
multilabel_topics = [
    [id2label[t] for t in multilabel if t in id2label]
    for multilabel in multilabel_topics
]

# %%
multilabel_topics_top = [
    [id2label[t] for t in multilabel if t in id2label]
    for multilabel in multilabel_topics_top
]

# %%
print("Number of topics:", len(set(topics)))
print(topics[:10])
print(multilabel_topics[:10]) 
print(multilabel_topics_top[:10])
# Out:
# Number of topics: 247
# ['26_ai_chatbots_intelligence_machines', '243_tutoring_answering_tutors_grading', '234_attention_transformers_softmax_transformer', '49_recommender_factorization_recommendation_recommendations', '9_learning_courses_ai_teaching', '99_graphbased_networks_graphs_graphstructured', '-1_learning_optimal_models_stochastic', '239_translations_multilingual_bilingual_translation', '243_tutoring_answering_tutors_grading', '-1_learning_optimal_models_stochastic']
# [['27_adversarial_adversarially_adversary_adversaries'], ['244_dropout_underfitting_overfitting_regularization'], ['235_memory_attention_memoryefficient_decoding'], ['50_ranking_rankings_ranked_rank'], ['10_learning_theory_algorithmic_papers'], ['100_reinforcement_policies_learning_policy'], ['16_microsoft_technologies_researchers_technology', '243_tutoring_answering_tutors_grading', '244_dropout_underfitting_overfitting_regularization'], ['240_adaptivemcmc_mcmc_hamiltonian_monte'], ['219_robust_robustly_outliers_estimation', '244_dropout_underfitting_overfitting_regularization'], ['244_dropout_underfitting_overfitting_regularization', '235_memory_attention_memoryefficient_decoding', '27_adversarial_adversarially_adversary_adversaries']]
# [['27_adversarial_adversarially_adversary_adversaries', '26_ai_chatbots_intelligence_machines', '13_forgetting_continual_learning_memory', '8_fairnessaware_fairness_discrimination_unfairness', '10_learning_theory_algorithmic_papers'], ['244_dropout_underfitting_overfitting_regularization', '219_robust_robustly_outliers_estimation', '235_memory_attention_memoryefficient_decoding', '122_planning_planner_learns_plans', '240_adaptivemcmc_mcmc_hamiltonian_monte'], ['235_memory_attention_memoryefficient_decoding', '206_captioning_multimodal_captions_languageimage', '207_shapenet_pointnet_3d_mesh', '83_detecting_detection_classifier_ood', '240_adaptivemcmc_mcmc_hamiltonian_monte'], ['50_ranking_rankings_ranked_rank', '182_tensors_tensor_tensorontensor_tensorsketch', '183_multilabel_labeling_labels_label', '176_stochastic_sde_sdes_variational', '15_automate_automated_automl_autosklearn'], ['10_learning_theory_algorithmic_papers', '15_automate_automated_automl_autosklearn', '11_strategic_classification_strategically_strategyproof', '24_odes_dynamics_dynamical_neural', '16_microsoft_technologies_researchers_technology'], ['100_reinforcement_policies_learning_policy', '45_optimization_algorithmic_learningbased_learning', '99_graphbased_networks_graphs_graphstructured', '107_lasso_sparse_gaussian_models', '44_topological_topologically_topology_homology'], ['16_microsoft_technologies_researchers_technology', '243_tutoring_answering_tutors_grading', '244_dropout_underfitting_overfitting_regularization', '236_minimax_minmax_ascent_optimization', '10_learning_theory_algorithmic_papers'], ['240_adaptivemcmc_mcmc_hamiltonian_monte', '235_memory_attention_memoryefficient_decoding', '219_robust_robustly_outliers_estimation', '217_audiovisual_voice_audio_voices', '236_minimax_minmax_ascent_optimization'], ['244_dropout_underfitting_overfitting_regularization', '219_robust_robustly_outliers_estimation', '240_adaptivemcmc_mcmc_hamiltonian_monte', '236_minimax_minmax_ascent_optimization', '59_bandits_bandit_reward_optimal'], ['244_dropout_underfitting_overfitting_regularization', '235_memory_attention_memoryefficient_decoding', '27_adversarial_adversarially_adversary_adversaries', '10_learning_theory_algorithmic_papers', '16_microsoft_technologies_researchers_technology']]

# %%
df.loc[: len(multilabel_topics) - 1, "assigned_topic_name"] = pd.Series(
    multilabel_topics
)
df["assigned_topic_name"] = df["assigned_topic_name"].apply(
    lambda x: ", ".join(x) if isinstance(x, list) else ""
)

# %%
import pandas as pd
import os
output_dir = "memento_data"
os.makedirs(output_dir, exist_ok=True)
output_file = os.path.join(output_dir, f"topic_results.csv")
df.to_csv(output_file, index=False)
print(f"\nSaved unique items to {output_file}")
# Out:
# Saved unique items to memento_data\topic_results.csv
