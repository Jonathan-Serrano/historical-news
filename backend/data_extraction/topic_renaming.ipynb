# %%
# %pip install langchain langchain-community langchain-ollama pandas
# Out:
# Requirement already satisfied: langchain in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (0.3.23)
# Requirement already satisfied: langchain-community in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (0.3.21)
# Requirement already satisfied: langchain-ollama in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (0.3.2)
# Requirement already satisfied: pandas in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (2.2.3)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.51 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langchain) (0.3.58)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langchain) (0.3.24)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langchain) (2.11.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langchain) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langchain-community) (3.11.16)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langchain-community) (2.8.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langchain-community) (2.2.4)
# Requirement already satisfied: ollama<1,>=0.4.4 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langchain-ollama) (0.4.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.51->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.51->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.51->langchain) (4.13.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.51->langchain) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\tan vo\documents\github\historical-news\backend\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import os
df = pd.read_csv("memento_data/bertopic_topics.csv")

# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser


import pandas as pd
from tqdm import tqdm
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser


def rename_topics_with_langchain(df, model_name="llama3", max_chars=500):
    """
    Rename BERTopic topics using LangChain and Ollama with a progress bar.

    Parameters:
    - df: pandas.DataFrame with BERTopic output, containing 'Topic', 'Representation', and 'Representative_Docs'.
    - model_name: Name of the Ollama model to use (e.g., 'llama3').
    - max_chars: Maximum number of characters to use from the representative document.

    Returns:
    - A copy of the DataFrame with a new column 'Generated_Name'.
    """
    llm = ChatOllama(model=model_name)

    prompt_template = ChatPromptTemplate.from_template(
        "Given the topic keywords: {keywords}\n"
        'And this document excerpt:\n"{doc}"\n\n'
        "That is generated from BertTopic, a topic modelling framework\n"
        "Suggest a short and descriptive topic name (1–5 words). Output only the name, no other text.\n"
    )

    parser = StrOutputParser()
    chain = prompt_template | llm | parser

    df_copy = df.copy()
    generated_names = []

    for _, row in tqdm(df_copy.iterrows(), total=len(df_copy), desc="Renaming topics"):
        if row["Topic"] == -1:
            generated_names.append("Outlier")
        else:
            rep_words = row["Representation"]
            doc_excerpt = ""
            if isinstance(row["Representative_Docs"], str):
                try:
                    doc_list = eval(row["Representative_Docs"])
                    if isinstance(doc_list, list) and doc_list:
                        doc_excerpt = ""
                        for doc in doc_list:
                            if len(doc) > max_chars:
                                doc = doc[:max_chars] + "..."
                            doc_excerpt += doc + "\n"
                except Exception:
                    doc_excerpt = ""
            try:
                name = chain.invoke({"keywords": rep_words, "doc": doc_excerpt}).strip()
            except Exception:
                name = "Error"
            generated_names.append(name)

    df_copy["Generated_Name"] = generated_names
    return df_copy

# %%
df_renamed = rename_topics_with_langchain(df, model_name="llama3", max_chars=500)
# Out:
# Renaming topics: 100%|██████████| 202/202 [01:03<00:00,  3.17it/s]

# %%
# Remove qutation from the newly generated name
df_renamed["Generated_Name"] = df_renamed["Generated_Name"].str.replace('"', '', regex=False)

# %%
df_renamed.to_csv("memento_data/bertopic_topics_renamed.csv", index=False)

# %%
df_renamed = pd.read_csv("memento_data/bertopic_topics_renamed.csv")

# %%
df = pd.read_csv("memento_data/newsCorpora_with_topic.csv")

# %%
df.head(10)
# Out:
#        id                                              title  \
# 0       2  Fed's Charles Plosser sees high bar for change...
# 1       5  Fed's Plosser: Nasty Weather Has Curbed Job Gr...
#
#                                  assigned_topic_name
# 0                           80_fed_bank_yellen_rates
# 1  110_jobs_job_unemployment_labor, 125_spending_...
# 2                        39_kunis_baby_pregnant_mila
# 3  188_elsa_anna_broadway_frozen, 23_lindsay_loha...
# 4               92_tries_boyfriend_movie_like middle
# 5   113_simpson_jessica_jessica simpson_eric johnson
# 6                      0_page_404_404 page_page page
# 7   113_simpson_jessica_jessica simpson_eric johnson
# 8  89_chromecast_tv_android tv_android, 63_amazon...
# 9                   106_zac_efron_zac efron_michelle

# %%
# Replace df.assigned_topic_name that have the old df.Name with new name from df_renamed.Generated_Name
topic2name_map = dict(zip(df_renamed.Name, df_renamed.Generated_Name))


df.assigned_topic_name = df.assigned_topic_name.apply(
    lambda x: (", ".join([
            topic2name_map.get(topic, topic)
            for topic in str(x).split(", ")
            if topic in topic2name_map
        ])
        if pd.notna(x)
        else x
    )
)

# %%
df.head()
# Out:
#        id                                              title  \
# 0       2  Fed's Charles Plosser sees high bar for change...
# 1       5  Fed's Plosser: Nasty Weather Has Curbed Job Gr...
# 2  280701  Only 2 people allowed in the delivery room: Pr...
# 3  285435  Actress And Civil Rights Activist Ruby Dee Die...
# 4  233727   VIDEO: Pat Sajak spins climate change on Twitter
#
#                                                  url               source  \
# 0  http://www.livemint.com/Politics/H2EvwJSK2VE6O...             Livemint
# 1  http://www.moneynews.com/Economy/federal-reser...            Moneynews
# 2  http://indiatoday.intoday.in/story/only-2-peop...          India Today
# 3  http://wegotthiscovered.com/movies/actress-civ...  We Got This Covered
# 4  http://www.tele-management.ca/2014/05/video-pa...       Telemanagement
#
#   category                       story_id                hostname  \
# 0        b  ddUyU0VZz0BRneMioxUPQVP6sIxvM        www.livemint.com
# 1        b  ddUyU0VZz0BRneMioxUPQVP6sIxvM       www.moneynews.com
# 2        e  dQEXtwpswiNW-4MJkBLcTFNZCQ42M   indiatoday.intoday.in
# 3        e  duy-eYWM3GLFeSMlLjm7WEMy_7YJM    wegotthiscovered.com
# 4        e  dqLZi-5Q-qdz3LMgOFGiDO9R2KyNM  www.tele-management.ca
#
#                  timestamp                                               body  \
# 0  2014-03-10 16:52:51.207  Paris/London/Atlanta: Federal Reserve Bank of ...
# 1  2014-03-10 16:52:52.027  The Federal Reserve meeting in the coming week...
# 2  2014-06-13 18:58:17.020  The 'Third Person' actress is expecting her fi...
# 3  2014-06-14 14:41:05.421  Award-winning actress Ruby Dee, best known for...
# 4  2014-05-21 21:18:17.155  This movie is about a woman who visits her boy...
#
#                                  assigned_topic_name
# 0                           Fed Interest Rate Policy
# 1  Job Market Trends, US Economic Downturn, Fed I...
# 2                        Mila Kunis Pregnancy Update
# 3  Frozen Broadway Musicals, Lindsay Lohan's Real...
# 4                           Relationship Drama Movie

# %%
df.to_csv("../data.csv", index=False)
df_renamed.to_csv("../topic_data.csv", index=False)
